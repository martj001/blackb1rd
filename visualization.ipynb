# %%
# Time clock vs trade clock

# %%
# Orderbook

# %% [markdown]
# ![LoB](./img/btcusdt-f-2021-05-09-01:40:08.477.gif)

# %%
# Orderbook
# Out:
# 100%|███████████████████████████████████████| 213/213 [00:00<00:00, 1866.67it/s]
# CPU times: user 3.48 s, sys: 369 ms, total: 3.85 s
# Wall time: 3.3 s
