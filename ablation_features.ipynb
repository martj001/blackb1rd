# %% [markdown]
# ## Ablation study: Feature set
#
# #### Feature set
# - v0: trade features only
# - v1: trade features + engineered features
# - v2: trade features + orderbook features v1
# - v3: trade features + orderbook features v2
#
# #### Feature selection
# - By Linear regression, select features with p-value < 0.05 on training set
#
# #### Model
# - __EMH__:  efficient market hypothesis, $\mathbb{E}[p_{t+1} - p_t] = 0$
# - __Linear__:  regression on price diff, $\mathbb{E}[p_{t+1} - p_t] = f(x_t)$, where $x_t$ = features
#
# #### Evaluation
# - $\operatorname{MSE}(p_{t+1} - p_t, f(x_t))$

# %%
# Evaluate feature set by training/testing MSE
# Out:
# ===== Training =====
# MSE EMH: 8.621
# MSE regression v0: 8.303
# MSE regression v1: 7.517
# MSE regression v2: 7.968
# MSE regression v3: 7.522
#
# ===== Testing =====
# MSE EMH: 6.462
# MSE regression v0: 6.226
# MSE regression v1: 5.696
# MSE regression v2: 5.957
# MSE regression v3: 5.706

# %% [markdown]
# ## Check feature correlation

# %%
# Correlation mat

# %% [markdown]
# ## Reduce feature skewness and kurtosis

# %%
# feature before transformation

# %%
# feature after transformation
